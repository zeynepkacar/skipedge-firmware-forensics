# %%
# !git clone https://github.com/nqminds/UniBOM.git
# Out:
# Cloning into 'UniBOM'...
# remote: Enumerating objects: 8442, done.
# remote: Counting objects: 100% (1924/1924), done.
# remote: Compressing objects: 100% (1009/1009), done.
# remote: Total 8442 (delta 901), reused 1764 (delta 791), pack-reused 6518 (from 1)
# Receiving objects: 100% (8442/8442), 16.98 MiB | 19.10 MiB/s, done.
# Resolving deltas: 100% (1763/1763), done.

# %%
# %cd UniBOM
# Out:
# /content/UniBOM

# %%
# !ls -la
# Out:
# total 36
# drwxr-xr-x 5 root root 4096 Aug  3 14:30 .
# drwxr-xr-x 1 root root 4096 Aug  3 14:30 ..
# -rw-r--r-- 1 root root  340 Aug  3 14:30 config.json
# drwxr-xr-x 8 root root 4096 Aug  3 14:30 .git
# drwxr-xr-x 3 root root 4096 Aug  3 14:30 .github
# -rw-r--r-- 1 root root  277 Aug  3 14:30 .gitignore
# -rw-r--r-- 1 root root   87 Aug  3 14:30 package-lock.json
# drwxr-xr-x 5 root root 4096 Aug  3 14:30 packages
# -rw-r--r-- 1 root root 1460 Aug  3 14:30 README.md

# %%
# !cat README.md
# Out:
# # Project Overview
#
# Welcome to the Software Bill of Materials (SBOM) Ecosystem repository. This repository hosts a suite of tools and services designed to handle SBOM generation, analysis, and data processing for Common Platform Enumerations (CPE) and related NIST datasets. The ecosystem is structured into multiple components, each addressing a specific functionality.
#
# ---
#
# ## Repository Structure
#
# This repository consists of the following major components:
#
# * Documentation Website
#
# Built with Docusaurus.
#
# Go to Documentation [README](packages/docusaurus/README.md)
#
# * SBOM Generation and Analysis CLI Tool
#
# A command-line interface tool to generate SBOMs and analyze their components for vulnerabilities over time.
#
# Go to SBOM CLI [README](packages/sbom-gap-cli/README.md)
#
# * API for Serving CPE Data
#
# A RESTful API that serves CPE data to the CLI tool and other web applications.
#
# Go to API [README](packages/sbom-gap-cli/nist-data-api/README.md)
#
# ...

# %%
# !cat packages/sbom-gap-cli/README.md
# Out:
# # SBOM-GAP(Generation and Analysis Platform) tool
# ---
#
# ## ⚠️ Important Notice: NIST Data Format Change
#
# > **Note (October 2025):**
# > The original pipeline for fetching and processing **CVE/CPE data** no longer works because the **NVD (NIST Vulnerability Database)** has permanently **retired its XML and legacy JSON 1.0 feeds** and migrated to the **JSON 2.0 REST API**.
# >
# > As a result, any steps in this repository that rely on downloading data from URLs such as
# > `https://nvd.nist.gov/feeds/json/...` or `https://nvd.nist.gov/feeds/xml/...`
# > will now fail or return **HTTP 403 Forbidden**.
# >
# > ✅ **Workaround:**
# > - Use the **CLI tool** to generate SBOMs.
# > - To explore CPE/CVE information or perform historical analysis, upload your SBOM to the following web app:
# >   🔗 [https://sbom.coreid.com/sbom-analysis](https://sbom.coreid.com/sbom-analysis)
# > - **Currently affected commands:**
# >   - `listCpeDetails`
# >   - `getCves`
# >   - `getCveInfo`
# ...

# %%
# !ls -la packages/sbom-gap-cli/
# Out:
# total 760
# drwxr-xr-x 9 root root   4096 Aug  3 14:30 .
# drwxr-xr-x 5 root root   4096 Aug  3 14:30 ..
# -rw-r--r-- 1 root root    587 Aug  3 14:30 docker-compose.yaml
# -rw-r--r-- 1 root root    654 Aug  3 14:30 Dockerfile
# -rw-r--r-- 1 root root     35 Aug  3 14:30 .eslintignore
# -rw-r--r-- 1 root root   1320 Aug  3 14:30 .eslintrc.json
# drwxr-xr-x 2 root root   4096 Aug  3 14:30 images
# -rwxr-xr-x 1 root root  21471 Aug  3 14:30 index.mjs
# -rw-r--r-- 1 root root  35149 Aug  3 14:30 LICENSE
# drwxr-xr-x 3 root root   4096 Aug  3 14:30 nist-data-api
# -rw-r--r-- 1 root root   1832 Aug  3 14:30 package.json
# -rw-r--r-- 1 root root 630269 Aug  3 14:30 package-lock.json
# -rw-r--r-- 1 root root     82 Aug  3 14:30 .prettierignore
# -rw-r--r-- 1 root root     32 Aug  3 14:30 .prettierrc
# -rw-r--r-- 1 root root  16738 Aug  3 14:30 README.md
# drwxr-xr-x 3 root root   4096 Aug  3 14:30 Sbom-GAP-Firmware-Prediction-Model
# drwxr-xr-x 2 root root   4096 Aug  3 14:30 scripts
# ...

# %%
# !curl -sSfL https://raw.githubusercontent.com/anchore/syft/main/install.sh | sh -s -- -b /usr/local/bin
# Out:
# [info] checking github for the current release tag
# [info] fetching release script for tag='v1.50.0'
# [info] checking github for the current release tag
# [info] using release tag='v1.50.0' version='1.50.0' os='linux' arch='amd64'
# [info] installed /usr/local/bin/syft

# %%
# !syft version
# Out:
# Application:   syft
# Version:       1.50.0
# BuildDate:     2026-07-28T17:38:13Z
# GitCommit:     16223e6dd7893fe578787658ceb876257483d404
# GitDescription: v1.50.0
# Platform:      linux/amd64
# GoVersion:     go1.26.3
# Compiler:      gc
# SchemaVersion: 16.1.10

# %%
# !syft dir:/content/sample_fw/_openwrt-sample.bin.extracted/squashfs-root -o json > /content/openwrt-sbom.json
# Out:
# [0000] ERROR could not determine source: no source providers were able to resolve the input "/content/sample_fw/_openwrt-sample.bin.extracted/squashfs-root"

# %%
# !wget -O /content/openwrt-sample.bin "https://downloads.openwrt.org/releases/23.05.5/targets/ramips/mt7621/openwrt-23.05.5-ramips-mt7621-tplink_archer-a6-v3-squashfs-sysupgrade.bin"
# Out:
# --2026-08-03 14:33:36--  https://downloads.openwrt.org/releases/23.05.5/targets/ramips/mt7621/openwrt-23.05.5-ramips-mt7621-tplink_archer-a6-v3-squashfs-sysupgrade.bin
# Resolving downloads.openwrt.org (downloads.openwrt.org)... 151.101.2.132, 151.101.66.132, 151.101.130.132, ...
# Connecting to downloads.openwrt.org (downloads.openwrt.org)|151.101.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6947416 (6.6M) [application/octet-stream]
# Saving to: ‘/content/openwrt-sample.bin’
#
# /content/openwrt-sa 100%[===================>]   6.62M  2.35MB/s    in 2.8s
#
# 2026-08-03 14:33:40 (2.35 MB/s) - ‘/content/openwrt-sample.bin’ saved [6947416/6947416]

# %%
# !binwalk -Me --run-as=root /content/openwrt-sample.bin
# Out:
# /bin/bash: line 1: binwalk: command not found

# %%
# !apt-get update -qq
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !apt-get install -y -qq binwalk
# Out:
# Extracting templates from packages: 100%
# (Reading database ... 118243 files and directories currently installed.)
# Preparing to unpack .../000-libpython3.10-dev_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking libpython3.10-dev:amd64 (3.10.12-1~22.04.16) over (3.10.12-1~22.04.15) ...
# Preparing to unpack .../001-libpython3.10_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking libpython3.10:amd64 (3.10.12-1~22.04.16) over (3.10.12-1~22.04.15) ...
# Preparing to unpack .../002-python3.10_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking python3.10 (3.10.12-1~22.04.16) over (3.10.12-1~22.04.15) ...
# Preparing to unpack .../003-libpython3.10-stdlib_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking libpython3.10-stdlib:amd64 (3.10.12-1~22.04.16) over (3.10.12-1~22.04.15) ...
# Preparing to unpack .../004-python3.10-minimal_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking python3.10-minimal (3.10.12-1~22.04.16) over (3.10.12-1~22.04.15) ...
# ...

# %%
# %%writefile /usr/lib/python3/dist-packages/imp.py
import importlib.util
import importlib.machinery
import types

def load_source(name, path):
    loader = importlib.machinery.SourceFileLoader(name, path)
    spec = importlib.util.spec_from_loader(name, loader)
    module = importlib.util.module_from_spec(spec)
    loader.exec_module(module)
    return module

def new_module(name):
    return types.ModuleType(name)
# Out:
# Overwriting /usr/lib/python3/dist-packages/imp.py

# %%
# !wget -O /content/openwrt-sample.bin "https://downloads.openwrt.org/releases/23.05.5/targets/ramips/mt7621/openwrt-23.05.5-ramips-mt7621-tplink_archer-a6-v3-squashfs-sysupgrade.bin"
# %cd /content
# !binwalk -Me --run-as=root openwrt-sample.bin
# Out:
# --2026-08-03 14:37:04--  https://downloads.openwrt.org/releases/23.05.5/targets/ramips/mt7621/openwrt-23.05.5-ramips-mt7621-tplink_archer-a6-v3-squashfs-sysupgrade.bin
# Resolving downloads.openwrt.org (downloads.openwrt.org)... 151.101.2.132, 151.101.66.132, 151.101.130.132, ...
# Connecting to downloads.openwrt.org (downloads.openwrt.org)|151.101.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6947416 (6.6M) [application/octet-stream]
# Saving to: ‘/content/openwrt-sample.bin’
#
# /content/openwrt-sa 100%[===================>]   6.62M  --.-KB/s    in 0.09s
#
# 2026-08-03 14:37:04 (73.5 MB/s) - ‘/content/openwrt-sample.bin’ saved [6947416/6947416]
#
# /content
# /usr/lib/python3/dist-packages/binwalk/core/magic.py:431: SyntaxWarning: invalid escape sequence '\.'
#   self.period = re.compile("\.")
#
# Scan Time:     2026-08-03 14:37:06
# Target File:   /content/openwrt-sample.bin
# MD5 Checksum:  50eab713c1c16d55d437cc8fd9e6d154
# ...

# %%
# !find /content -maxdepth 3 -type d -name "squashfs-root"
# Out:
# /content/_openwrt-sample.bin.extracted/squashfs-root

# %%
# !syft dir:/content/_openwrt-sample.bin.extracted/squashfs-root -o json > /content/openwrt-sbom.json
# !cat /content/openwrt-sbom.json | python3 -c "import json,sys; d=json.load(sys.stdin); print('Tespit edilen bileşen sayısı:', len(d.get('artifacts', [])))"
# Out:
#  ⠙ Cataloging contents             ━━━━━━━━━━━━━━━━━━━━  438d8ccf9d47b1d09570e67632c05fe60c733113599dbc530a4020f6221290f4
#    └── ⠙ Packages
#          ├── ⠋
#          └── ⠋ [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal)
#
#
#
#          ├── ⠙
#
#
#
#
#
#          ├── ⠋
#          ├── ⠋
#          └── ⠋ [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal)
#
#
#
#          ├── ⠋
#
#          └── ⠋ [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal)
#
#
#
#          ├── ⠙ Dpkg db cataloger
#
#          ├── ⠋
#          └── ⠋ [0000]  WARN no explicit name and version provided for directory source, deriving artifact ID from the given path (which is not ideal)
#
#
#
#
#          ├── ⠙
#
#          ├── ⠋
# ...

# %%
# !curl -sSfL https://raw.githubusercontent.com/anchore/grype/main/install.sh | sh -s -- -b /usr/local/bin
# !grype version
# Out:
# [info] checking github for the current release tag
# [info] fetching release script for tag='v0.116.1'
# [info] checking github for the current release tag
# [info] using release tag='v0.116.1' version='0.116.1' os='linux' arch='amd64'
# [info] installed /usr/local/bin/grype
# Application:         grype
# Version:             0.116.1
# BuildDate:           2026-07-28T21:39:06Z
# GitCommit:           30394f177175da63ae36b35cdd809c248eb4de7f
# GitDescription:      v0.116.1
# Platform:            linux/amd64
# GoVersion:           go1.26.3
# Compiler:            gc
# Syft Version:        v1.50.0
# Supported DB Schema: 6

# %%
# !grype sbom:/content/openwrt-sbom.json -o json > /content/openwrt-vulns.json
# !cat /content/openwrt-vulns.json | python3 -c "import json,sys; d=json.load(sys.stdin); print('Tespit edilen zafiyet sayısı:', len(d.get('matches', [])))"
# Out:
#  ⠙ Scanning for vulnerabilities    ━━━━━━━━━━━━━━━━━━━━  [0 vulnerability matches]
#    ├── by severity: 0 critical, 0 high, 0 medium, 0 low, 0 negligible
#    └── by status:   0 fixed, 0 not-fixed, 0 ignored
# [0000]  WARN unable to create distro from linux distribution error=unable to determine distro type
# [0132]  WARN Unable to determine the OS distribution of some packages. This may result in missing vulnerabilities. You may specify a distro using: --distro <distro>:<version>
# [0132]  WARN distro detection failed: linux release info was present but distro type could not be determined
#
#
#    ├── by severity: 1 critical, 0 high, 5 medium, 2 low, 0 negligible
#    └── by status:   0 fixed, 8 not-fixed, 0 ignored
#
#
#
#
#  ⠹ Scanning for vulnerabilities    ━━━━━━━━━━━━━━━━━━━━  [0 vulnerability matches]
#
#
#
#
#
#
#  ✔ Scanned for vulnerabilities     [8 vulnerability matches]
#
#
#
#
#
# Tespit edilen zafiyet sayısı: 8
