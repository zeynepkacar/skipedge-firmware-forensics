# %%
# !git clone https://github.com/NESA-Lab/FirmRCA.git
# Out:
# Cloning into 'FirmRCA'...
# remote: Enumerating objects: 345, done.
# remote: Counting objects: 100% (345/345), done.
# remote: Compressing objects: 100% (222/222), done.
# remote: Total 345 (delta 142), reused 318 (delta 116), pack-reused 0 (from 0)
# Receiving objects: 100% (345/345), 12.23 MiB | 29.46 MiB/s, done.
# Resolving deltas: 100% (142/142), done.

# %%
# %cd FirmRCA
# Out:
# /content/FirmRCA

# %%
# !ls -la
# Out:
# total 340
# drwxr-xr-x 9 root root   4096 Aug  3 12:05 .
# drwxr-xr-x 1 root root   4096 Aug  3 12:05 ..
# -rw-r--r-- 1 root root   2417 Aug  3 12:05 config.yml
# -rw-r--r-- 1 root root   4949 Aug  3 12:05 dataset.py
# drwxr-xr-x 4 root root   4096 Aug  3 12:05 fuzzware-emulator
# drwxr-xr-x 8 root root   4096 Aug  3 12:05 .git
# -rw-r--r-- 1 root root    228 Aug  3 12:05 .gitignore
# -rw-r--r-- 1 root root  35823 Aug  3 12:05 LICENSE
# -rw-r--r-- 1 root root  17195 Aug  3 12:05 main.py
# drwxr-xr-x 5 root root   4096 Aug  3 12:05 pomp
# drwxr-xr-x 5 root root   4096 Aug  3 12:05 pompplusplus
# -rw-r--r-- 1 root root    320 Aug  3 12:05 pyproject.toml
# -rw-r--r-- 1 root root      5 Aug  3 12:05 .python-version
# -rw-r--r-- 1 root root   5032 Aug  3 12:05 README.md
# drwxr-xr-x 5 root root   4096 Aug  3 12:05 src
# drwxr-xr-x 2 root root   4096 Aug  3 12:05 test_c_capnproto
# drwxr-xr-x 2 root root   4096 Aug  3 12:05 testsuites
# -rw-r--r-- 1 root root 221080 Aug  3 12:05 uv.lock

# %%
# !cat README.md
# Out:
# [![DOI](https://zenodo.org/badge/DOI/10.5281/zenodo.15623400.svg)](https://doi.org/10.5281/zenodo.15623400) [![DOI](https://img.shields.io/github/license/NESA-Lab/FirmRCA.svg)](https://github.com/NESA-Lab/FirmRCA?tab=GPL-3.0-1-ov-file) [![Static Badge](https://img.shields.io/badge/IEEE%20S%26P-10.1109%2FSP61157.2025.00002-green)](https://www.computer.org/csdl/proceedings-article/sp/2025/223600a002/21B7PVDny6I)
#
# # FirmRCA
#
# Embedded Firmware Root Cause Analysis.
#
# This repo contains the source code of the paper "FirmRCA: Towards Post-Fuzzing Analysis on ARM Embedded Firmware with Efficient Event-based Fault Localization"
#
# ## NOTE
#
# ...

# %%
# !git clone https://github.com/capstone-engine/capstone.git
# Out:
# Cloning into 'capstone'...
# remote: Enumerating objects: 48103, done.
# remote: Counting objects: 100% (893/893), done.
# remote: Compressing objects: 100% (560/560), done.
# remote: Total 48103 (delta 652), reused 337 (delta 332), pack-reused 47210 (from 4)
# Receiving objects: 100% (48103/48103), 69.08 MiB | 17.26 MiB/s, done.
# Resolving deltas: 100% (32972/32972), done.

# %%
# %cd capstone
# Out:
# /content/FirmRCA/capstone

# %%
# !git reset --hard 622059530f172b1570a424e3f7ef5fda8c00dab0
# Out:
# HEAD is now at 62205953 [v6] Move meta-programming macros for ARM64/AArch64 to capstone.h (#2201)

# %%
# !./make.sh
# Out:
#   CC      cs.o
#   CC      utils.o
#   CC      SStream.o
#   CC      MCInstrDesc.o
#   CC      MCRegisterInfo.o
#   CC      MCInst.o
#   CC      MCInstPrinter.o
#   CC      Mapping.o
#   CC      arch/ARM/ARMBaseInfo.o
#   CC      arch/ARM/ARMDisassembler.o
#   CC      arch/ARM/ARMDisassemblerExtension.o
#   CC      arch/ARM/ARMInstPrinter.o
#   CC      arch/ARM/ARMMapping.o
# In file included from arch/ARM/ARMInstPrinter.c:64:
# arch/ARM/ARMGenAsmWriter.inc:9626:6: warning: no previous prototype for ‘printInstruction’ [-Wmissing-prototypes]
#  9626 | void printInstruction(MCInst *MI, uint64_t Address, SStream *O)
#       |      ^~~~~~~~~~~~~~~~
# arch/ARM/ARMGenAsmWriter.inc:12436:13: warning: no previous prototype for ‘getRegisterName’ [-Wmissing-prototypes]
# 12436 | const char *getRegisterName(unsigned RegNo, unsigned AltIdx)
#       |             ^~~~~~~~~~~~~~~
#   CC      arch/ARM/ARMModule.o
#   CC      arch/AArch64/AArch64BaseInfo.o
# ...

# %%
# !./make.sh install
# Out:
# make[1]: Entering directory '/content/FirmRCA/capstone/cstool'
# make[1]: Nothing to be done for 'all'.
# make[1]: Leaving directory '/content/FirmRCA/capstone/cstool'
# make -C tests
# make[1]: Entering directory '/content/FirmRCA/capstone/tests'
# make[1]: Nothing to be done for 'all'.
# make[1]: Leaving directory '/content/FirmRCA/capstone/tests'
# install -m0755 ./libcapstone.so.5 ./tests/
# cd ./tests/ && rm -f libcapstone.so && ln -s libcapstone.so.5 libcapstone.so
# mkdir -p /usr/lib
# install -m0755 ./libcapstone.so.5 /usr/lib
# cd /usr/lib && rm -f libcapstone.so && ln -s libcapstone.so.5 libcapstone.so
# install -m0644 ./libcapstone.a /usr/lib
# mkdir -p /usr/include/capstone
# install -m0644 include/capstone/*.h /usr/include/capstone
# mkdir -p /usr/lib/pkgconfig
# install -m0644 ./capstone.pc /usr/lib/pkgconfig
# mkdir -p /usr/bin
# install -m0755 cstool/cstool /usr/bin

# %%
# %cd ..
# Out:
# /content/FirmRCA

# %%
# !wget -qO- https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.12.1 x86_64-unknown-linux-gnu
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !source $HOME/.local/bin/env
# Out:
# /bin/bash: line 1: /root/.local/bin/env: No such file or directory

# %%
# !wget -qO- https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.12.1 x86_64-unknown-linux-gnu
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !find / -iname "uv" -type f 2>/dev/null
# Out:
# /usr/local/bin/uv

# %%
# !uv --version
# Out:
# uv 0.12.1 (x86_64-unknown-linux-gnu)

# %%
# %cd /content/FirmRCA
# Out:
# /content/FirmRCA

# %%
# !uv sync
# Out:
# Using CPython 3.10.12 interpreter at: /usr/bin/python3.10
# Creating virtual environment at: .venv
# Resolved 20 packages in 2ms
# Prepared 17 packages in 2.66s
# Installed 17 packages in 162ms
#  + contourpy==1.3.2
#  + cycler==0.12.1
#  + et-xmlfile==2.0.0
#  + fonttools==4.61.1
#  + kiwisolver==1.4.9
#  + matplotlib==3.10.8
#  + numpy==2.2.6
#  + openpyxl==3.1.5
#  + packaging==25.0
#  + pandas==2.3.3
#  + pillow==12.1.0
#  + pyparsing==3.3.1
#  + python-dateutil==2.9.0.post0
#  + pytz==2025.2
#  + pyyaml==6.0.3
#  + six==1.17.0
#  + tzdata==2025.3

# %%
# %cd /content/FirmRCA/src
# Out:
# /content/FirmRCA/src

# %%
# !chmod +x ./autogen.sh

# %%
# !./autogen.sh
# Out:
# configure.ac:10: installing './compile'
# configure.ac:26: installing './config.guess'
# configure.ac:26: installing './config.sub'
# configure.ac:6: installing './install-sh'
# configure.ac:6: installing './missing'
# src/Makefile.am: installing './depcomp'
# src/Makefile.am:24: warning: variable 'ablation1_SOURCES' is defined but no program or
# src/Makefile.am:24: library has 'ablation1' as canonical name (possible typo)
# src/Makefile.am:30: warning: variable 'ablation2_SOURCES' is defined but no program or
# src/Makefile.am:30: library has 'ablation2' as canonical name (possible typo)
# src/Makefile.am:36: warning: variable 'ablation3_SOURCES' is defined but no program or
# src/Makefile.am:36: library has 'ablation3' as canonical name (possible typo)
# src/Makefile.am:22: warning: variable 'ablation1_LDADD' is defined but no program or
# src/Makefile.am:22: library has 'ablation1' as canonical name (possible typo)
# ...

# %%
# !./configure
# Out:
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a race-free mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether the compiler supports GNU C... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to enable C11 features... none needed
# checking whether gcc understands -c and -o together... yes
# checking whether make supports the include directive... yes (GNU style)
# checking dependency style of gcc... gcc3
# checking for stdio.h... yes
# checking for stdlib.h... yes
# ...

# %%
# %cd /content/FirmRCA/src/src
# Out:
# /content/FirmRCA/src/src

# %%
# !make
# Out:
# gcc -DHAVE_CONFIG_H -I. -I..  -msse4.1  -DFRCA -DNDEBUG -DENABLE_LOG -DVERBOSE -DMEMAC -I ../include -Wl,-rpath=../lib -L../lib -g -O2 -MT reverselog-access_memory.o -MD -MP -MF .deps/reverselog-access_memory.Tpo -c -o reverselog-access_memory.o `test -f 'access_memory.c' || echo './'`access_memory.c
# mv -f .deps/reverselog-access_memory.Tpo .deps/reverselog-access_memory.Po
# gcc -DHAVE_CONFIG_H -I. -I..  -msse4.1  -DFRCA -DNDEBUG -DENABLE_LOG -DVERBOSE -DMEMAC -I ../include -Wl,-rpath=../lib -L../lib -g -O2 -MT reverselog-alias_manager.o -MD -MP -MF .deps/reverselog-alias_manager.Tpo -c -o reverselog-alias_manager.o `test -f 'alias_manager.c' || echo './'`alias_manager.c
# mv -f .deps/reverselog-alias_manager.Tpo .deps/reverselog-alias_manager.Po
# ...

# %%
# %cd /content/FirmRCA
# Out:
# /content/FirmRCA

# %%
# !cd testsuites && unzip -q testsuites-demo.zip

# %%
# !ls -la testsuites/
# Out:
# total 13924
# drwxr-xr-x  5 root root     4096 Aug  3 12:20 .
# drwxr-xr-x 11 root root     4096 Aug  3 12:16 ..
# drwxr-xr-x  2 root root     4096 May  6  2024 p2im-12
# drwxr-xr-x  2 root root     4096 May  6  2024 p2im-22
# -rw-r--r--  1 root root 14234472 Aug  3 12:05 testsuites-demo.zip
# drwxr-xr-x  2 root root     4096 May  6  2024 zephyr-54

# %%
# !uv run main.py --name=p2im-12

# %%
# !ls -la testsuites/p2im-12/
# Out:
# total 34296
# drwxr-xr-x 2 root root     4096 Aug  3 12:21 .
# drwxr-xr-x 5 root root     4096 Aug  3 12:20 ..
# -rw-r--r-- 1 root root     4547 Aug  3 13:56 execution-capnproto-nolog-1.log
# -rw-r--r-- 1 root root    44352 Dec  7  2023 firmware.bin
# -rw-r--r-- 1 root root  1685420 Dec  7  2023 instlist.reverse
# -rw-r--r-- 1 root root 23824080 Dec  7  2023 loglist.reverse
# -rw-r--r-- 1 root root  9377336 Dec  7  2023 memac.bin
# -rw-r--r-- 1 root root      332 Dec  7  2023 README.md
# -rw-r--r-- 1 root root   157930 Dec  7  2023 state-out.txt

# %%
# !cat testsuites/p2im-12/execution-capnproto-nolog-1.log
# Out:
# Current Time:2026-08-03 21:30:45
# max_rev_ins_num: 168542
# root_cause_rev_idx: 168542
# Runtime when start reverse execution is 0s : 643ms
# Runtime when finish reverse execution is 1499s : 930ms
# Runtime when start resolve is 1499s : 930ms
# Runtime when finish resolve is 1499s : 982ms
# Runtime when start backward tainting is 1499s : 982ms
# better be 1 : acnum = 1
# better be 1 : acnum = 1
# ======= The total number of tainted instruction is 53. These instruction are:
# Current Instruction at 2 with score 99 is 0x8008628 : ldr.w	r0, [r3, r2, lsl #2]
# Current Instruction at 3 with score 99 is 0x8008626 : ldr	r3, [pc, #0x18]
# Current Instruction at 4 with score 99 is 0x8008622 : ldrb.w	r2, [r0, #0x44]
# Current Instruction at 7 with score 99 is 0x8008c1e : mov	r0, r4
# Current Instruction at 8 with score 99 is 0x8008c1a : add.w	r4, r0, #0xd4
# Current Instruction at 28 with score 99 is 0x8003274 : mov	r0, r4
# Current Instruction at 37 with score 99 is 0x8003262 : ldr	r4, [r0]
# ...
