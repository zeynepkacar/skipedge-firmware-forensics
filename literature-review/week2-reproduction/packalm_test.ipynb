# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynepkacar/skipedge-firmware-forensics/blob/main/packalm_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O /content/packalm.zip "https://zenodo.org/records/14091136/files/PackALM.zip?download=1"
# Out:
# --2026-08-03 14:43:24--  https://zenodo.org/records/14091136/files/PackALM.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.153, 188.185.48.75, 188.184.103.118, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2596128887 (2.4G) [application/octet-stream]
# Saving to: ‘/content/packalm.zip’
#
# /content/packalm.zi 100%[===================>]   2.42G  3.68MB/s    in 10m 26s
#
# 2026-08-03 14:53:51 (3.96 MB/s) - ‘/content/packalm.zip’ saved [2596128887/2596128887]
