# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynepkacar/skipedge-firmware-forensics/blob/main/ffxe_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/rchtsang/ffxe.git
# Out:
# Cloning into 'ffxe'...
# remote: Enumerating objects: 904, done.
# remote: Counting objects: 100% (904/904), done.
# remote: Compressing objects: 100% (475/475), done.
# remote: Total 904 (delta 527), reused 769 (delta 395), pack-reused 0 (from 0)
# Receiving objects: 100% (904/904), 24.70 MiB | 22.73 MiB/s, done.
# Resolving deltas: 100% (527/527), done.

# %%
# %cd ffxe
# Out:
# /content/ffxe

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !ls -la
# Out:
# total 48
# drwxr-xr-x 7 root root 4096 Jul 30 22:19 .
# drwxr-xr-x 1 root root 4096 Jul 30 22:19 ..
# -rw-r--r-- 1 root root  242 Jul 30 22:19 environment.yml
# drwxr-xr-x 4 root root 4096 Jul 30 22:19 examples
# drwxr-xr-x 4 root root 4096 Jul 30 22:19 ffxe
# drwxr-xr-x 8 root root 4096 Jul 30 22:19 .git
# -rw-r--r-- 1 root root  123 Jul 30 22:19 .gitignore
# -rw-r--r-- 1 root root 1067 Jul 30 22:19 LICENSE
# -rw-r--r-- 1 root root 1311 Jul 30 22:19 README.md
# drwxr-xr-x 2 root root 4096 Jul 30 22:19 scripts
# -rw-r--r-- 1 root root  104 Jul 30 22:19 setup.py
# drwxr-xr-x 2 root root 4096 Jul 30 22:19 tests

# %%
# !ls -la examples
# Out:
# total 16
# drwxr-xr-x  4 root root 4096 Jul 30 22:19 .
# drwxr-xr-x  7 root root 4096 Jul 30 22:19 ..
# drwxr-xr-x 11 root root 4096 Jul 30 22:19 real-world
# drwxr-xr-x  2 root root 4096 Jul 30 22:19 unit-tests

# %%
# !cat README.md
# Out:
# # FFXE
#
# FFXE is a CFG recovery tool for Cortex-M based embedded firmware binaries.
#
# It was first presented at USENIX 2024 in [_FFXE: Dynamic Control Flow Graph Recovery for Embedded Firmware Binaries_](https://www.usenix.org/conference/usenixsecurity24/presentation/tsang) as a way to recover indirect calls to asynchronously-registered interrupt handler functions using dynamic forced execution.
# For citation and reading, please refer to the [author revision](https://rctsang.github.io/publications/usenix24-ffxe/ffxe-revision.pdf), which corrects a reporting inaccuracy in the case study.
# The original artifacts have been saved and can be found [in this fork](https://github.com/aseec-lab/ffxe-usenix24).
#
# ...

# %%
# !cat setup.py
# Out:
# from setuptools import setup, find_packages
#
# setup(name='ffxe', version='1.1', packages=find_packages())

# %%
# !cat environment.yml
# Out:
# name: ffxe
# channels:
#   - conda-forge
# dependencies:
#   - ipykernel=6.29.5
#   - pip=24.2
#   - python=3.11.10
#   - pip:
#     - capstone==5.0.3
#     - dill==0.3.8
#     - networkx==3.3
#     - pyelftools==0.31
#     - pyyaml==6.0.2
#     - unicorn==2.0.1.post1

# %%
# !ls -la examples/real-world
# Out:
# total 44
# drwxr-xr-x 11 root root 4096 Jul 30 22:19 .
# drwxr-xr-x  4 root root 4096 Jul 30 22:19 ..
# drwxr-xr-x  2 root root 4096 Jul 30 22:19 chargehr_18_128
# drwxr-xr-x  2 root root 4096 Jul 30 22:19 chargehr_18_32
# drwxr-xr-x  2 root root 4096 Jul 30 22:19 flex_7_64_flash
# drwxr-xr-x  2 root root 4096 Jul 30 22:19 flex_7_81_flash
# drwxr-xr-x  2 root root 4096 Jul 30 22:19 flex_7_88_flash
# drwxr-xr-x  2 root root 4096 Jul 30 22:19 switchmate-bright_1_46
# drwxr-xr-x  2 root root 4096 Jul 30 22:19 switchmate-bright_2_9_11
# drwxr-xr-x  2 root root 4096 Jul 30 22:19 switchmate-light_2_21
# drwxr-xr-x  2 root root 4096 Jul 30 22:19 switchmate-light_2_99_16

# %%
# !pip install capstone==5.0.3 dill==0.3.8 networkx==3.3 pyelftools==0.31 pyyaml==6.0.2 unicorn==2.0.1.post1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 55.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.5/180.5 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 73.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.3
#     Uninstalling PyYAML-6.0.3:
#       Successfully uninstalled PyYAML-6.0.3
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.6.1
#     Uninstalling networkx-3.6.1:
#       Successfully uninstalled networkx-3.6.1
# ...

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/ffxe
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for ffxe
# ...

# %%
# !ls -la scripts
# Out:
# total 16
# drwxr-xr-x 2 root root 4096 Jul 30 22:19 .
# drwxr-xr-x 8 root root 4096 Jul 30 22:24 ..
# -rw-r--r-- 1 root root 4283 Jul 30 22:19 visualize-cfg.py

# %%
# !cat scripts/*.py
# Out:
# import os
# import argparse
# import json
# import re
# from glob import glob
# from pathlib import Path
#
# import dill
# import yaml
#
# import ffxe.models
# from ffxe.utils import *
#
# FW_NAME_PTRN = re.compile(r"(?P<fwname>[\w-]+)-(?P<engine>\w+)-cfg\.pkl")
#
# PARENT_DIR = os.path.dirname(os.path.realpath(__file__))
#
# def load_cfg(path : str):
#     assert os.path.exists(path)
#     with open(path, 'rb') as pf:
#         return dill.load(pf)
#
# def load_pd(path : str):
#     assert os.path.exists(path)
#     with open(path, 'rb') as pd_file:
#         return yaml.load(pd_file, yaml.Loader)
#
# parser = argparse.ArgumentParser(prog="visualize-cfg.py",
#     description="generate a text-based visualization of a cfg")
# parser.add_argument('--path', type=str, default=f"{PARENT_DIR}/../tests/cfgs/unit-tests",
#     help="path to pickled cfg or directory containing pickled cfgs")
# parser.add_argument('--pd', type=str, default=f"{PARENT_DIR}/../mmaps/nrf52832.yml",
# ...

# %%
# !sed -n '1,300p' README.md
# Out:
# # FFXE
#
# FFXE is a CFG recovery tool for Cortex-M based embedded firmware binaries.
#
# It was first presented at USENIX 2024 in [_FFXE: Dynamic Control Flow Graph Recovery for Embedded Firmware Binaries_](https://www.usenix.org/conference/usenixsecurity24/presentation/tsang) as a way to recover indirect calls to asynchronously-registered interrupt handler functions using dynamic forced execution.
# For citation and reading, please refer to the [author revision](https://rctsang.github.io/publications/usenix24-ffxe/ffxe-revision.pdf), which corrects a reporting inaccuracy in the case study.
# The original artifacts have been saved and can be found [in this fork](https://github.com/aseec-lab/ffxe-usenix24).
#
# ...

# %%
# !ls -la ffxe
# Out:
# total 132
# drwxr-xr-x 4 root root  4096 Jul 30 22:19 .
# drwxr-xr-x 8 root root  4096 Jul 30 22:24 ..
# drwxr-xr-x 2 root root  4096 Jul 30 22:19 arch
# -rw-r--r-- 1 root root 66514 Jul 30 22:19 engine.py
# -rw-r--r-- 1 root root  4272 Jul 30 22:19 ihex.py
# -rw-r--r-- 1 root root   351 Jul 30 22:19 __init__.py
# -rw-r--r-- 1 root root  1943 Jul 30 22:19 mappings.py
# drwxr-xr-x 2 root root  4096 Jul 30 22:19 mmaps
# -rw-r--r-- 1 root root 25281 Jul 30 22:19 models.py
# -rw-r--r-- 1 root root   683 Jul 30 22:19 utils.py

# %%
# !ls -la tests
# Out:
# total 20
# drwxr-xr-x 2 root root 4096 Jul 30 22:19 .
# drwxr-xr-x 8 root root 4096 Jul 30 22:24 ..
# -rw-r--r-- 1 root root 6189 Jul 30 22:19 test-real.py
# -rw-r--r-- 1 root root 2337 Jul 30 22:19 test-unit.py

# %%
# !cat tests/test-real.py
# Out:
# import os
# import argparse
# from os.path import (
#     basename, splitext, exists, realpath,
#     dirname, relpath, isdir
# )
# from copy import deepcopy
# from glob import glob
# from time import perf_counter
# from datetime import datetime
# from pathlib import Path
#
# import dill
#
# from ffxe import *
#
# """
# script to run ffxe on real-world samples
# """
#
# make_timestamp = lambda: datetime.now().strftime('%y%m%d-%H%M%S')
#
# PARENT_DIR = dirname(realpath(__file__))
# PROJ_ROOT = dirname(PARENT_DIR)
# SAMPLES_DIR = f"{PROJ_ROOT}/examples/real-world"
# OUT_DIR = f"{PARENT_DIR}/cfgs/real-world"
#
# def generate_highlighted_disasm_txt(ffxe, graph):
#     ffxe.fw.disassemble(graph)
#
#     disasm_txt = deepcopy(ffxe.fw.disasm_txt)
#     for block in ffxe.cfg.bblocks.values():
#         insn_addr = block.addr
#         for insn in ffxe.cs.disasm(
#                 ffxe.uc.mem_read(block.addr, block.size), block.size):
#             try:
# ...

# %%
# !python tests/test-real.py
# Out:
# analyzing target: examples/real-world/chargehr_18_128
# specified base address: 0x8000000
# vector table offsets: 0x8000200 0x8009c00
# "chargehr_18_128.bin"              : { "blocks":  1636, "edges":  2609,  "elapsed": "   14.829112006 s" }
# analyzing target: examples/real-world/chargehr_18_32
# specified base address: 0x8000000
# vector table offsets: 0x8000200 0x8009c00
# "chargehr_18_32.bin"               : { "blocks":  2570, "edges":  4080,  "elapsed": "    8.047924001 s" }
# analyzing target: examples/real-world/flex_7_64_flash
# specified base address: 0x8000000
# vector table offsets: 0x8000200 0x800a000
# "flex_7_64_flash.bin"              : { "blocks":  4690, "edges":  7640,  "elapsed": "   18.114539200 s" }
# analyzing target: examples/real-world/flex_7_81_flash
# specified base address: 0x8000000
# vector table offsets: 0x8000200 0x800a000
# "flex_7_81_flash.bin"              : { "blocks":  4704, "edges":  7662,  "elapsed": "   19.214429505 s" }
# ...

# %%
# !cp tests/ffxe-real-cfg-results-*.json /content/drive/MyDrive/
# Out:
# cp: cannot create regular file '/content/drive/MyDrive/': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.makedirs('/content/drive/MyDrive/literatur-colab/FFXE', exist_ok=True)

# %%
# !cp tests/ffxe-real-cfg-results-*.json /content/drive/MyDrive/literatur-colab/FFXE/
