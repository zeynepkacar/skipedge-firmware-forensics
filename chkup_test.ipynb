# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynepkacar/skipedge-firmware-forensics/blob/main/chkup_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/WUSTL-CSPL/ChkUp.git
# Out:
# Cloning into 'ChkUp'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 79 (delta 7), reused 68 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (79/79), 157.25 KiB | 2.67 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd ChkUp
# Out:
# /content/ChkUp

# %%
# !ls -la
# Out:
# total 64
# drwxr-xr-x 9 root root 4096 Jul 31 20:08 .
# drwxr-xr-x 1 root root 4096 Jul 31 20:08 ..
# -rwxr-xr-x 1 root root 1186 Jul 31 20:08 chkup_run.sh
# drwxr-xr-x 2 root root 4096 Jul 31 20:08 configs
# drwxr-xr-x 4 root root 4096 Jul 31 20:08 exec_pth_rec
# drwxr-xr-x 8 root root 4096 Jul 31 20:08 .git
# -rw-r--r-- 1 root root   20 Jul 31 20:08 .gitignore
# -rw-r--r-- 1 root root  381 Jul 31 20:08 .gitmodules
# -rw-r--r-- 1 root root 3705 Jul 31 20:08 main.py
# -rw-r--r-- 1 root root 5167 Jul 31 20:08 README.md
# -rw-r--r-- 1 root root  168 Jul 31 20:08 requirements.txt
# drwxr-xr-x 2 root root 4096 Jul 31 20:08 utilities
# drwxr-xr-x 3 root root 4096 Jul 31 20:08 ver_proc_recog
# drwxr-xr-x 2 root root 4096 Jul 31 20:08 vuln_discov
# drwxr-xr-x 6 root root 4096 Jul 31 20:08 vuln_val

# %%
# !cat README.md
# Out:
# # ChkUp
# ChkUp is a tool designed to <ins>C</ins>heck for firmware <ins>U</ins>pdate vulnerabilities. ChkUp can extract program execution paths from a firmware update procedure and identify vulnerable verification steps within that procedure. To use ChkUp, users need to run our program from the command line, providing the file paths of unpacked firmware images. The expected output comprises vulnerability identification results (i.e., vulnerable verification procedures) and intermediate structural, syntactic, and semantic analysis results for programs related to firmware updates.
#
#
# ## Dependencies
# - python 3.6
# - java 11.0.23
# - npm 6.14.4
# - python packages ([requirements.txt](./requirements.txt))
# - ghidra 10.1.2 (https://github.com/NationalSecurityAgency/ghidra/releases)
#
#
# ## Usage
# 1. Setup the testing environment;
# 2. Specify necessary paths in the config files;
# ...
